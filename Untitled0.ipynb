# %% [markdown]
# <a href="https://colab.research.google.com/github/NewtonCh/-rvore-Radial-Fernanda/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly pandas

# %%
import pandas as pd
import plotly.express as px

# Estrutura de tópicos corrigida, removendo os itens "não-folha" (ancestrais).
# Foram removidas as linhas que eram apenas prefixos de outras mais longas.
data_paths = [
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "crítica cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "estudos antropológicos na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "interculturalidade na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "mediação cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "orientação cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "tradução cultural"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "tradução cultural comentada"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "condicionantes culturais na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "referência cultural"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "referentes culturais"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "item cultural específico"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "capoeira em tradução"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "compadrito na tradução cultural"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "cultura nordestina na tradução"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "mitologia indígena na tradução"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "adaptação transcultural"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "crioulização na tradução"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "tradução no acolhimento linguístico"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "tradução de cultura pop"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "imigração na tradução", "imigração alemã na tradução"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "imigrantes na tradução", "imigrantes haitianos na tradução"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de literatura de migração"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de narrativas de migrantes"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de narrativas de refugiados"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de textos sobre migração"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de textos sobre refugiados"],
    ["Estudos culturais da tradução", "tradução e formas culturais discursivas", "tradução de ditos"],
    ["Estudos culturais da tradução", "tradução e formas culturais discursivas", "tradução de expressões populares"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras classicistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras da era vitoriana"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras de vanguarda"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do cubanismo"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do período elisabetano"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do regionalismo de 30"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do Século de Ouro"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do século XVII"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do Segundo Reinado"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras futuristas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras modernistas", "tradução de obras modernistas no Brasil"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras renascentistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras românticas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras surrealistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras veristas"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação comunitária"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação de conferência", "interpretação de conferências multilíngues"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação educacional"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação em equipe"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação na área da saúde", "interpretação em cenários médicos"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação na área da saúde", "interpretação médica no Brasil"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação simultânea", "interpretação simultânea artística", "performance em língua de sinais"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação simultânea", "interpretação simultânea de conferência"],
]


# Corrigindo a inconsistência 'areas' vs 'áreas' para agrupar os dados corretamente.
# Embora a maioria dos problemas de 'areas' tenha sido resolvida pela remoção dos pais,
# esta correção ainda é uma boa prática para garantir consistência.
for path in data_paths:
    for i, item in enumerate(path):
        if item == "areas e modalidades de interpretação":
            path[i] = "áreas e modalidades de interpretação"


# Define os nomes das colunas para os níveis da hierarquia.
colunas = ['Nivel_1', 'Nivel_2', 'Nivel_3', 'Nivel_4', 'Nivel_5']

# Cria o DataFrame.
df = pd.DataFrame(data_paths, columns=colunas)

# Adiciona uma coluna 'Contagem' para dar um valor a cada caminho.
# Se não for fornecida, o Plotly tentará agregar, o que pode ser problemático.
df['Contagem'] = 1

# Cria o gráfico de explosão solar.
fig = px.sunburst(
    df,
    path=colunas,
    values='Contagem',
    title='Estrutura Hierárquica dos Estudos da Tradução e Interpretação'
)

# Atualiza o layout para melhor visualização.
fig.update_layout(
    margin=dict(t=50, l=25, r=25, b=25),
    font=dict(size=12)
)

# Exibe o gráfico (em ambientes como Jupyter Notebook)
fig.show()

# Salva o gráfico como um arquivo HTML interativo.
fig.write_html("grafico_estudos_traducao.html")

print("O gráfico foi salvo como 'grafico_estudos_traducao.html'")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Estrutura de tópicos corrigida, removendo os itens "não-folha" (ancestrais).
# Foram removidas as linhas que eram apenas prefixos de outras mais longas.
data_paths = [
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "crítica cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "estudos antropológicos na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "interculturalidade na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "mediação cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "orientação cultural na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "tradução cultural"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "tradução cultural comentada"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "condicionantes culturais na tradução"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "referência cultural"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "referentes culturais"],
    ["Estudos culturais da tradução", "abordagens e fundamentos teóricos", "item cultural específico"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "capoeira em tradução"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "compadrito na tradução cultural"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "cultura nordestina na tradução"],
    ["Estudos culturais da tradução", "contextos históricos e culturais específicos", "mitologia indígena na tradução"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "adaptação transcultural"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "crioulização na tradução"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "tradução no acolhimento linguístico"],
    ["Estudos culturais da tradução", "dinâmicas transculturais e híbridas", "tradução de cultura pop"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "imigração na tradução", "imigração alemã na tradução"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "imigrantes na tradução", "imigrantes haitianos na tradução"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de literatura de migração"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de narrativas de migrantes"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de narrativas de refugiados"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de textos sobre migração"],
    ["Estudos culturais da tradução", "migração, exílio e refúgio na tradução", "migração na tradução", "tradução de textos sobre refugiados"],
    ["Estudos culturais da tradução", "tradução e formas culturais discursivas", "tradução de ditos"],
    ["Estudos culturais da tradução", "tradução e formas culturais discursivas", "tradução de expressões populares"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras classicistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras da era vitoriana"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras de vanguarda"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do cubanismo"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do período elisabetano"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do regionalismo de 30"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do Século de Ouro"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do século XVII"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras do Segundo Reinado"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras futuristas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras modernistas", "tradução de obras modernistas no Brasil"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras renascentistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras românticas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras surrealistas"],
    ["Estudos culturais da tradução", "tradução e tradição literária", "tradução de obras veristas"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação comunitária"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação de conferência", "interpretação de conferências multilíngues"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação educacional"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação em equipe"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação na área da saúde", "interpretação em cenários médicos"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação na área da saúde", "interpretação médica no Brasil"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação simultânea", "interpretação simultânea artística", "performance em língua de sinais"],
    ["Estudos da interpretação", "áreas e modalidades de interpretação", "interpretação simultânea", "interpretação simultânea de conferência"],
]


# Corrigindo a inconsistência 'areas' vs 'áreas' para agrupar os dados corretamente.
# Embora a maioria dos problemas de 'areas' tenha sido resolvida pela remoção dos pais,
# esta correção ainda é uma boa prática para garantir consistência.
for path in data_paths:
    for i, item in enumerate(path):
        if item == "areas e modalidades de interpretação":
            path[i] = "áreas e modalidades de interpretação"


# Define os nomes das colunas para os níveis da hierarquia.
colunas = ['Nivel_1', 'Nivel_2', 'Nivel_3', 'Nivel_4', 'Nivel_5']

# Cria o DataFrame.
df = pd.DataFrame(data_paths, columns=colunas)

# Adiciona uma coluna 'Contagem' para dar um valor a cada caminho.
# Se não for fornecida, o Plotly tentará agregar, o que pode ser problemático.
df['Contagem'] = 1

# Cria o gráfico de explosão solar.
fig = px.sunburst(
    df,
    path=colunas,
    values='Contagem',
    title='Estrutura Hierárquica dos Estudos da Tradução e Interpretação'
)

# Atualiza o layout para melhor visualização.
fig.update_layout(
    margin=dict(t=50, l=25, r=25, b=25),
    font=dict(size=12)
)

# Exibe o gráfico (em ambientes como Jupyter Notebook)
fig.show()

# Salva o gráfico como um arquivo HTML interativo.
fig.write_html("grafico_estudos_traducao.html")

print("O gráfico foi salvo como 'grafico_estudos_traducao.html'")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
